# %% [markdown]
# <a href="https://colab.research.google.com/github/Asritha-525/NASSCOM/blob/main/Python_core_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
# We'll imagine this is sensor data from various devices.
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}

# --- Task 1: Python Fundamentals, Lists, Tuples, Sets, Dictionaries, Indexing & Slicing ---
print("\n--- Task 1: Data Generation and Basic Structures ---")

# 1.1 Generate a list of 100 simulated sensor readings.
#    Each reading should be a tuple: (timestamp_str, device_id, device_type, location, value).
#    - timestamp_str: Format as 'YYYY-MM-DD HH:MM:SS'
#    - device_id: A unique ID for each reading (e.g., 'DEV001', 'DEV002', etc., up to 100 unique IDs).
#    - device_type: Randomly chosen from DEVICE_TYPES.
#    - location: Randomly chosen from LOCATIONS.
#    - value: Random float within READING_RANGES for its device_type (round to 2 decimal places).
# Store these in a list called 'raw_sensor_data'.

# Your code for Task 1.1 here:
import random
import datetime

DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']

LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']

READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),
    'Humidity_Sensor': (30.0, 80.0),
    'Pressure_Sensor': (980.0, 1030.0),
    'Light_Sensor': (100, 1000)
}

raw_sensor_data = []

for i in range(1, 101):
    timestamp_str = (datetime.datetime.now() + datetime.timedelta(seconds=i)).strftime("%Y-%m-%d %H:%M:%S")
    device_id = f"DEV{i:03d}"
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)
    min_value, max_value = READING_RANGES[device_type]
    value = round(random.uniform(min_value, max_value), 2)
    reading = (timestamp_str, device_id, device_type, location, value)
    raw_sensor_data.append(reading)

for reading in raw_sensor_data:
    print(reading)





# 1.2 From 'raw_sensor_data', create a list named 'temperature_readings' containing only the readings
#     where 'device_type' is 'Temperature_Sensor'.
#     Each item in 'temperature_readings' should be a dictionary with keys:
#     'timestamp', 'device_id', 'location', 'temperature_celsius'.

# Your code for Task 1.2 here:
temperature_readings = []

for reading in raw_sensor_data:
    if reading[2] == "Temperature_Sensor":
        temperature_readings.append({
            "timestamp": reading[0],
            "device_id": reading[1],
            "location": reading[3],
            "temperature_celsius": reading[4]
        })

for temp in temperature_readings:
    print(temp)




# 1.3 Create a set named 'unique_locations' containing all unique locations from 'raw_sensor_data'.

# Your code for Task 1.3 here:
unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])

print(unique_locations)



# 1.4 Create a dictionary named 'device_stats' where keys are 'device_type' and values are
#     a tuple: (min_value, max_value) observed for that device type across all readings.
#     Initialize with sensible large/small values.

# Your code for Task 1.4 here:
device_stats = {
    "Temperature_Sensor": (float("inf"), float("-inf")),
    "Humidity_Sensor": (float("inf"), float("-inf")),
    "Pressure_Sensor": (float("inf"), float("-inf")),
    "Light_Sensor": (float("inf"), float("-inf"))
}

for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]
    min_value, max_value = device_stats[device_type]
    device_stats[device_type] = (min(min_value, value), max(max_value, value))

print(device_stats)




# 1.5: Advanced Indexing and Slicing (Lists and Strings)
print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")

# Let's use 'raw_sensor_data' and create a sample string for these tasks.
sample_string = "PythonProgrammingIsFun"

# 1.5.1 List Slicing: Extract elements from the 10th to the 20th (inclusive) from 'raw_sensor_data'.
#       Store the result in 'sliced_readings_1'.
#       Then, extract every 5th reading from 'raw_sensor_data' starting from the beginning.
#       Store the result in 'sliced_readings_2'.

# Your code for Task 1.5.1 here:
sliced_readings_1 = raw_sensor_data[9:20]
sliced_readings_2 = raw_sensor_data[::5]

print(sliced_readings_1)
print(sliced_readings_2)



# 1.5.2 String Slicing: Extract the substring "Programming" from 'sample_string'.
#       Store the result in 'substring_1'.
#       Then, extract the substring "nohtyP" (the reverse of "Python") from 'sample_string' using slicing.
#       Store the result in 'substring_2'.

# Your code for Task 1.5.2 here:
substring_1 = sample_string[6:17]
substring_2 = sample_string[5::-1]

print(substring_1)
print(substring_2)


# 1.5.3 Mixed Slicing: Access the 'device_type' of the 5th reading in 'raw_sensor_data' using indexing.
#       Store it in 'fifth_reading_device_type'.
#       Then, from 'fifth_reading_device_type', extract the last 6 characters (e.g., 'Sensor' from 'Temperature_Sensor').
#       Store it in 'device_type_suffix'.

# Your code for Task 1.5.3 here:
fifth_reading_device_type = raw_sensor_data[4][2]
device_type_suffix = fifth_reading_device_type[-6:]

print(fifth_reading_device_type)
print(device_type_suffix)




# --- Task 2: Writing and Using Functions in Python ---
print("\n--- Task 2: Function Definitions and Usage ---")

# 2.1 Write a function `get_readings_by_location(readings_list, target_location)`
#     that takes the 'raw_sensor_data' list and a 'target_location' string.
#     It should return a list of all readings (as tuples) for that specific location.

# Your code for Task 2.1 here:
def get_readings_by_location(readings_list, target_location):
    result = []
    for reading in readings_list:
        if reading[3] == target_location:
            result.append(reading)
    return result

location_readings = get_readings_by_location(raw_sensor_data, "Lab1")

for reading in location_readings:
    print(reading)


# 2.2 Write a function `calculate_average_temperature(temp_data_list)`
#     that takes the 'temperature_readings' list (list of dictionaries).
#     It should calculate and return the average temperature. Return 0.0 if the list is empty.

# Your code for Task 2.2 here:
def calculate_average_temperature(temp_data_list):
    if len(temp_data_list) == 0:
        return 0.0

    total = 0
    for reading in temp_data_list:
        total += reading["temperature_celsius"]

    return total / len(temp_data_list)

average_temperature = calculate_average_temperature(temperature_readings)
print(average_temperature)


# 2.3 Write a function `generate_report_line(reading_dict)`
#     that takes a single temperature reading dictionary.
#     It should return a formatted string like:
#     "[{timestamp}] Device {device_id} at {location}: {temperature_celsius}°C"

# Your code for Task 2.3 here:
def generate_report_line(reading_dict):
    return f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"

for reading in temperature_readings:
    print(generate_report_line(reading))



# --- Task 3: Working with Core Python Libraries (os, datetime, random) ---
print("\n--- Task 3: Core Library Usage ---")

# 3.1 Use the `os` module to create a new directory named 'sensor_reports'
#     in the current working directory, if it doesn't already exist.

# Your code for Task 3.1 here:
reports_dir = 'sensor_reports'
if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")


# 3.2 Calculate the duration between the first and last timestamp in 'raw_sensor_data'.
#     Convert string timestamps to datetime objects first.
#     Print the duration in days, hours, and minutes.

# Your code for Task 3.2 here:
if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    # Convert string to datetime object
    # The format string must exactly match the timestamp string
    date_format = '%Y-%m-%d %H:%M:%S'
    first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)

    duration = last_dt - first_dt

    days = duration.days
    seconds = duration.total_seconds()
    hours = int(seconds // 3600) % 24 # Calculate remaining hours after full days
    minutes = int((seconds % 3600) // 60) # Calculate remaining minutes after full hours

    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")


# 3.3 Generate a list of 5 random integer values between 100 and 200 (inclusive)
#     using the `random` module. Store it in 'random_values'.

# Your code for Task 3.3 here:



# --- Task 4: File Handling in Python ---
print("\n--- Task 4: File I/O ---")

# 4.1 Write all 'temperature_readings' to a file named 'sensor_reports/temperature_report.txt'.
#     Each line in the file should be generated using the `generate_report_line` function.

# Your code for Task 4.1 here:
report_filename = os.path.join(reports_dir, 'temperature_report.txt')
try:
    with open(report_filename, 'w') as f:
        for reading_dict in temperature_readings:
            line = generate_report_line(reading_dict)
            f.write(line + '\n')
    print(f"\nTemperature report written to '{report_filename}'.")
except IOError as e:
    print(f"\nError writing file '{report_filename}': {e}")


# 4.2 Read the content of 'sensor_reports/temperature_report.txt' back into a list of strings
#     named 'read_report_lines'. Print the first 3 lines.

# Your code for Task 4.2 here:





print("\n--- Exercise Complete! ---")
print("Great job completing the intermediate Python exercise.")
print("Review your code and outputs to ensure correctness and understanding of all concepts.")
print("Consider adding more complex scenarios or user inputs for further practice.")
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
# ('2026-07-19 15:41:54', 'DEV001', 'Humidity_Sensor', 'OfficeA', 79.71)
# ('2026-07-19 15:41:55', 'DEV002', 'Humidity_Sensor', 'OfficeB', 34.89)
# ('2026-07-19 15:41:56', 'DEV003', 'Temperature_Sensor', 'Lab1', 24.12)
# ('2026-07-19 15:41:57', 'DEV004', 'Humidity_Sensor', 'Lab1', 48.89)
# ('2026-07-19 15:41:58', 'DEV005', 'Pressure_Sensor', 'Lab1', 996.41)
# ('2026-07-19 15:41:59', 'DEV006', 'Light_Sensor', 'OfficeB', 446.82)
# ('2026-07-19 15:42:00', 'DEV007', 'Humidity_Sensor', 'OfficeA', 76.69)
# ('2026-07-19 15:42:01', 'DEV008', 'Temperature_Sensor', 'OfficeB', 18.99)
# ('2026-07-19 15:42:02', 'DEV009', 'Humidity_Sensor', 'OfficeB', 47.62)
# ('2026-07-19 15:42:03', 'DEV010', 'Light_Sensor', 'OfficeB', 475.89)
# ('2026-07-19 15:42:04', 'DEV011', 'Pressure_Sensor', 'Warehouse', 1009.19)
# ('2026-07-19 15:42:05', 'DEV012', 'Pressure_Sensor', 'OfficeA', 989.38)
# ('2026-07-19 15:42:06', 'DEV013', 'Temperature_Sensor', 'Lab2', 22.15)
# ('2026-07-19 15:42:07', 'DEV014', 'Pressure_Sensor', 'Warehouse', 1028.22)
# ('2026-07-19 15:42:08', 'DEV015', 'Light_Sensor', 'OfficeA', 163.03)
# ('2026-07-19 15:42:09', 'DEV016', 'Humidity_Sensor', 'Lab2', 36.01)
# ('2026-07-19 15:42:10', 'DEV017', 'Pressure_Sensor', 'Lab1', 1005.44)
# ('2026-07-19 15:42:11', 'DEV018', 'Temperature_Sensor', 'OfficeB', 28.76)
# ('2026-07-19 15:42:12', 'DEV019', 'Light_Sensor', 'Lab1', 882.81)
# ('2026-07-19 15:42:13', 'DEV020', 'Temperature_Sensor', 'Lab2', 28.95)
# ('2026-07-19 15:42:14', 'DEV021', 'Light_Sensor', 'Warehouse', 578.54)
# ('2026-07-19 15:42:15', 'DEV022', 'Light_Sensor', 'OfficeB', 446.91)
# ('2026-07-19 15:42:16', 'DEV023', 'Light_Sensor', 'OfficeB', 535.5)
# ('2026-07-19 15:42:17', 'DEV024', 'Temperature_Sensor', 'OfficeB', 20.75)
# ('2026-07-19 15:42:18', 'DEV025', 'Light_Sensor', 'Lab1', 363.95)
# ('2026-07-19 15:42:19', 'DEV026', 'Humidity_Sensor', 'OfficeB', 45.18)
# ('2026-07-19 15:42:20', 'DEV027', 'Light_Sensor', 'Lab2', 424.62)
# ('2026-07-19 15:42:21', 'DEV028', 'Temperature_Sensor', 'OfficeB', 28.64)
# ('2026-07-19 15:42:22', 'DEV029', 'Light_Sensor', 'Lab2', 411.3)
# ('2026-07-19 15:42:23', 'DEV030', 'Pressure_Sensor', 'OfficeB', 1012.33)
# ('2026-07-19 15:42:24', 'DEV031', 'Pressure_Sensor', 'OfficeA', 1025.65)
# ('2026-07-19 15:42:25', 'DEV032', 'Light_Sensor', 'Warehouse', 498.95)
# ('2026-07-19 15:42:26', 'DEV033', 'Humidity_Sensor', 'Warehouse', 42.88)
# ('2026-07-19 15:42:27', 'DEV034', 'Pressure_Sensor', 'Warehouse', 994.37)
# ('2026-07-19 15:42:28', 'DEV035', 'Pressure_Sensor', 'Warehouse', 992.35)
# ('2026-07-19 15:42:29', 'DEV036', 'Pressure_Sensor', 'Lab1', 1023.88)
# ('2026-07-19 15:42:30', 'DEV037', 'Temperature_Sensor', 'Lab2', 26.48)
# ('2026-07-19 15:42:31', 'DEV038', 'Humidity_Sensor', 'Lab1', 40.43)
# ('2026-07-19 15:42:32', 'DEV039', 'Light_Sensor', 'OfficeA', 670.74)
# ('2026-07-19 15:42:33', 'DEV040', 'Temperature_Sensor', 'Lab2', 29.01)
# ('2026-07-19 15:42:34', 'DEV041', 'Pressure_Sensor', 'Lab2', 1022.99)
# ('2026-07-19 15:42:35', 'DEV042', 'Light_Sensor', 'Lab2', 293.06)
# ('2026-07-19 15:42:36', 'DEV043', 'Temperature_Sensor', 'OfficeA', 23.12)
# ('2026-07-19 15:42:37', 'DEV044', 'Temperature_Sensor', 'Warehouse', 19.05)
# ('2026-07-19 15:42:38', 'DEV045', 'Temperature_Sensor', 'Warehouse', 28.28)
# ('2026-07-19 15:42:39', 'DEV046', 'Temperature_Sensor', 'Lab1', 29.94)
# ('2026-07-19 15:42:40', 'DEV047', 'Humidity_Sensor', 'OfficeB', 76.14)
# ('2026-07-19 15:42:41', 'DEV048', 'Light_Sensor', 'Warehouse', 560.8)
# ('2026-07-19 15:42:42', 'DEV049', 'Pressure_Sensor', 'Lab2', 1002.78)
# ('2026-07-19 15:42:43', 'DEV050', 'Temperature_Sensor', 'OfficeA', 23.27)
# ('2026-07-19 15:42:44', 'DEV051', 'Pressure_Sensor', 'Warehouse', 1027.65)
# ('2026-07-19 15:42:45', 'DEV052', 'Pressure_Sensor', 'OfficeA', 987.29)
# ('2026-07-19 15:42:46', 'DEV053', 'Temperature_Sensor', 'Lab2', 18.4)
# ('2026-07-19 15:42:47', 'DEV054', 'Pressure_Sensor', 'Lab1', 1017.48)
# ('2026-07-19 15:42:48', 'DEV055', 'Pressure_Sensor', 'Lab1', 992.9)
# ('2026-07-19 15:42:49', 'DEV056', 'Pressure_Sensor', 'Warehouse', 981.58)
# ('2026-07-19 15:42:50', 'DEV057', 'Temperature_Sensor', 'Lab2', 29.28)
# ('2026-07-19 15:42:51', 'DEV058', 'Light_Sensor', 'Lab2', 155.96)
# ('2026-07-19 15:42:52', 'DEV059', 'Light_Sensor', 'Lab1', 484.42)
# ('2026-07-19 15:42:53', 'DEV060', 'Humidity_Sensor', 'OfficeB', 31.11)
# ('2026-07-19 15:42:54', 'DEV061', 'Humidity_Sensor', 'Warehouse', 78.87)
# ('2026-07-19 15:42:55', 'DEV062', 'Pressure_Sensor', 'Warehouse', 1019.28)
# ('2026-07-19 15:42:56', 'DEV063', 'Humidity_Sensor', 'OfficeA', 62.0)
# ('2026-07-19 15:42:57', 'DEV064', 'Pressure_Sensor', 'OfficeA', 989.65)
# ('2026-07-19 15:42:58', 'DEV065', 'Temperature_Sensor', 'Lab1', 24.27)
# ('2026-07-19 15:42:59', 'DEV066', 'Light_Sensor', 'OfficeA', 239.32)
# ('2026-07-19 15:43:00', 'DEV067', 'Pressure_Sensor', 'Lab2', 1001.6)
# ('2026-07-19 15:43:01', 'DEV068', 'Light_Sensor', 'OfficeA', 312.87)
# ('2026-07-19 15:43:02', 'DEV069', 'Pressure_Sensor', 'Lab2', 990.15)
# ('2026-07-19 15:43:03', 'DEV070', 'Light_Sensor', 'Lab1', 872.72)
# ('2026-07-19 15:43:04', 'DEV071', 'Pressure_Sensor', 'OfficeB', 1009.46)
# ('2026-07-19 15:43:05', 'DEV072', 'Light_Sensor', 'Lab2', 420.79)
# ('2026-07-19 15:43:06', 'DEV073', 'Light_Sensor', 'Warehouse', 647.88)
# ('2026-07-19 15:43:07', 'DEV074', 'Light_Sensor', 'OfficeB', 470.91)
# ('2026-07-19 15:43:08', 'DEV075', 'Temperature_Sensor', 'OfficeB', 26.65)
# ('2026-07-19 15:43:09', 'DEV076', 'Pressure_Sensor', 'Warehouse', 989.14)
# ('2026-07-19 15:43:10', 'DEV077', 'Temperature_Sensor', 'Warehouse', 24.01)
# ('2026-07-19 15:43:11', 'DEV078', 'Light_Sensor', 'Warehouse', 105.16)
# ('2026-07-19 15:43:12', 'DEV079', 'Pressure_Sensor', 'OfficeA', 1008.43)
# ('2026-07-19 15:43:13', 'DEV080', 'Light_Sensor', 'Lab2', 239.38)
# ('2026-07-19 15:43:14', 'DEV081', 'Pressure_Sensor', 'Lab1', 1014.3)
# ('2026-07-19 15:43:15', 'DEV082', 'Pressure_Sensor', 'Lab2', 1004.22)
# ('2026-07-19 15:43:16', 'DEV083', 'Humidity_Sensor', 'OfficeB', 37.92)
# ('2026-07-19 15:43:17', 'DEV084', 'Humidity_Sensor', 'Lab1', 66.37)
# ('2026-07-19 15:43:18', 'DEV085', 'Humidity_Sensor', 'Warehouse', 47.15)
# ('2026-07-19 15:43:19', 'DEV086', 'Humidity_Sensor', 'Lab2', 41.48)
# ('2026-07-19 15:43:20', 'DEV087', 'Humidity_Sensor', 'OfficeA', 72.44)
# ('2026-07-19 15:43:21', 'DEV088', 'Pressure_Sensor', 'Warehouse', 1006.53)
# ('2026-07-19 15:43:22', 'DEV089', 'Temperature_Sensor', 'Lab1', 25.09)
# ('2026-07-19 15:43:23', 'DEV090', 'Humidity_Sensor', 'OfficeB', 41.3)
# ('2026-07-19 15:43:24', 'DEV091', 'Humidity_Sensor', 'Lab1', 51.5)
# ('2026-07-19 15:43:25', 'DEV092', 'Humidity_Sensor', 'OfficeA', 41.56)
# ('2026-07-19 15:43:26', 'DEV093', 'Pressure_Sensor', 'Lab1', 996.82)
# ('2026-07-19 15:43:27', 'DEV094', 'Pressure_Sensor', 'Warehouse', 1018.1)
# ('2026-07-19 15:43:28', 'DEV095', 'Humidity_Sensor', 'Lab2', 43.77)
# ('2026-07-19 15:43:29', 'DEV096', 'Pressure_Sensor', 'Warehouse', 990.12)
# ('2026-07-19 15:43:30', 'DEV097', 'Light_Sensor', 'Lab1', 175.94)
# ('2026-07-19 15:43:31', 'DEV098', 'Pressure_Sensor', 'Lab2', 1022.54)
# ('2026-07-19 15:43:32', 'DEV099', 'Pressure_Sensor', 'Lab2', 1023.23)
# ('2026-07-19 15:43:33', 'DEV100', 'Pressure_Sensor', 'OfficeA', 997.1)
# {'timestamp': '2026-07-19 15:41:56', 'device_id': 'DEV003', 'location': 'Lab1', 'temperature_celsius': 24.12}
# {'timestamp': '2026-07-19 15:42:01', 'device_id': 'DEV008', 'location': 'OfficeB', 'temperature_celsius': 18.99}
# {'timestamp': '2026-07-19 15:42:06', 'device_id': 'DEV013', 'location': 'Lab2', 'temperature_celsius': 22.15}
# {'timestamp': '2026-07-19 15:42:11', 'device_id': 'DEV018', 'location': 'OfficeB', 'temperature_celsius': 28.76}
# {'timestamp': '2026-07-19 15:42:13', 'device_id': 'DEV020', 'location': 'Lab2', 'temperature_celsius': 28.95}
# {'timestamp': '2026-07-19 15:42:17', 'device_id': 'DEV024', 'location': 'OfficeB', 'temperature_celsius': 20.75}
# {'timestamp': '2026-07-19 15:42:21', 'device_id': 'DEV028', 'location': 'OfficeB', 'temperature_celsius': 28.64}
# {'timestamp': '2026-07-19 15:42:30', 'device_id': 'DEV037', 'location': 'Lab2', 'temperature_celsius': 26.48}
# {'timestamp': '2026-07-19 15:42:33', 'device_id': 'DEV040', 'location': 'Lab2', 'temperature_celsius': 29.01}
# {'timestamp': '2026-07-19 15:42:36', 'device_id': 'DEV043', 'location': 'OfficeA', 'temperature_celsius': 23.12}
# {'timestamp': '2026-07-19 15:42:37', 'device_id': 'DEV044', 'location': 'Warehouse', 'temperature_celsius': 19.05}
# {'timestamp': '2026-07-19 15:42:38', 'device_id': 'DEV045', 'location': 'Warehouse', 'temperature_celsius': 28.28}
# {'timestamp': '2026-07-19 15:42:39', 'device_id': 'DEV046', 'location': 'Lab1', 'temperature_celsius': 29.94}
# {'timestamp': '2026-07-19 15:42:43', 'device_id': 'DEV050', 'location': 'OfficeA', 'temperature_celsius': 23.27}
# {'timestamp': '2026-07-19 15:42:46', 'device_id': 'DEV053', 'location': 'Lab2', 'temperature_celsius': 18.4}
# {'timestamp': '2026-07-19 15:42:50', 'device_id': 'DEV057', 'location': 'Lab2', 'temperature_celsius': 29.28}
# {'timestamp': '2026-07-19 15:42:58', 'device_id': 'DEV065', 'location': 'Lab1', 'temperature_celsius': 24.27}
# {'timestamp': '2026-07-19 15:43:08', 'device_id': 'DEV075', 'location': 'OfficeB', 'temperature_celsius': 26.65}
# {'timestamp': '2026-07-19 15:43:10', 'device_id': 'DEV077', 'location': 'Warehouse', 'temperature_celsius': 24.01}
# {'timestamp': '2026-07-19 15:43:22', 'device_id': 'DEV089', 'location': 'Lab1', 'temperature_celsius': 25.09}
# {'Warehouse', 'Lab1', 'OfficeA', 'Lab2', 'OfficeB'}
# {'Temperature_Sensor': (18.4, 29.94), 'Humidity_Sensor': (31.11, 79.71), 'Pressure_Sensor': (981.58, 1028.22), 'Light_Sensor': (105.16, 882.81)}
#
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---
# [('2026-07-19 15:42:03', 'DEV010', 'Light_Sensor', 'OfficeB', 475.89), ('2026-07-19 15:42:04', 'DEV011', 'Pressure_Sensor', 'Warehouse', 1009.19), ('2026-07-19 15:42:05', 'DEV012', 'Pressure_Sensor', 'OfficeA', 989.38), ('2026-07-19 15:42:06', 'DEV013', 'Temperature_Sensor', 'Lab2', 22.15), ('2026-07-19 15:42:07', 'DEV014', 'Pressure_Sensor', 'Warehouse', 1028.22), ('2026-07-19 15:42:08', 'DEV015', 'Light_Sensor', 'OfficeA', 163.03), ('2026-07-19 15:42:09', 'DEV016', 'Humidity_Sensor', 'Lab2', 36.01), ('2026-07-19 15:42:10', 'DEV017', 'Pressure_Sensor', 'Lab1', 1005.44), ('2026-07-19 15:42:11', 'DEV018', 'Temperature_Sensor', 'OfficeB', 28.76), ('2026-07-19 15:42:12', 'DEV019', 'Light_Sensor', 'Lab1', 882.81), ('2026-07-19 15:42:13', 'DEV020', 'Temperature_Sensor', 'Lab2', 28.95)]
# [('2026-07-19 15:41:54', 'DEV001', 'Humidity_Sensor', 'OfficeA', 79.71), ('2026-07-19 15:41:59', 'DEV006', 'Light_Sensor', 'OfficeB', 446.82), ('2026-07-19 15:42:04', 'DEV011', 'Pressure_Sensor', 'Warehouse', 1009.19), ('2026-07-19 15:42:09', 'DEV016', 'Humidity_Sensor', 'Lab2', 36.01), ('2026-07-19 15:42:14', 'DEV021', 'Light_Sensor', 'Warehouse', 578.54), ('2026-07-19 15:42:19', 'DEV026', 'Humidity_Sensor', 'OfficeB', 45.18), ('2026-07-19 15:42:24', 'DEV031', 'Pressure_Sensor', 'OfficeA', 1025.65), ('2026-07-19 15:42:29', 'DEV036', 'Pressure_Sensor', 'Lab1', 1023.88), ('2026-07-19 15:42:34', 'DEV041', 'Pressure_Sensor', 'Lab2', 1022.99), ('2026-07-19 15:42:39', 'DEV046', 'Temperature_Sensor', 'Lab1', 29.94), ('2026-07-19 15:42:44', 'DEV051', 'Pressure_Sensor', 'Warehouse', 1027.65), ('2026-07-19 15:42:49', 'DEV056', 'Pressure_Sensor', 'Warehouse', 981.58), ('2026-07-19 15:42:54', 'DEV061', 'Humidity_Sensor', 'Warehouse', 78.87), ('2026-07-19 15:42:59', 'DEV066', 'Light_Sensor', 'OfficeA', 239.32), ('2026-07-19 15:43:04', 'DEV071', 'Pressure_Sensor', 'OfficeB', 1009.46), ('2026-07-19 15:43:09', 'DEV076', 'Pressure_Sensor', 'Warehouse', 989.14), ('2026-07-19 15:43:14', 'DEV081', 'Pressure_Sensor', 'Lab1', 1014.3), ('2026-07-19 15:43:19', 'DEV086', 'Humidity_Sensor', 'Lab2', 41.48), ('2026-07-19 15:43:24', 'DEV091', 'Humidity_Sensor', 'Lab1', 51.5), ('2026-07-19 15:43:29', 'DEV096', 'Pressure_Sensor', 'Warehouse', 990.12)]
# Programming
# nohtyP
# Pressure_Sensor
# Sensor
#
# --- Task 2: Function Definitions and Usage ---
# ('2026-07-19 15:41:56', 'DEV003', 'Temperature_Sensor', 'Lab1', 24.12)
# ('2026-07-19 15:41:57', 'DEV004', 'Humidity_Sensor', 'Lab1', 48.89)
# ('2026-07-19 15:41:58', 'DEV005', 'Pressure_Sensor', 'Lab1', 996.41)
# ('2026-07-19 15:42:10', 'DEV017', 'Pressure_Sensor', 'Lab1', 1005.44)
# ('2026-07-19 15:42:12', 'DEV019', 'Light_Sensor', 'Lab1', 882.81)
# ('2026-07-19 15:42:18', 'DEV025', 'Light_Sensor', 'Lab1', 363.95)
# ('2026-07-19 15:42:29', 'DEV036', 'Pressure_Sensor', 'Lab1', 1023.88)
# ('2026-07-19 15:42:31', 'DEV038', 'Humidity_Sensor', 'Lab1', 40.43)
# ('2026-07-19 15:42:39', 'DEV046', 'Temperature_Sensor', 'Lab1', 29.94)
# ('2026-07-19 15:42:47', 'DEV054', 'Pressure_Sensor', 'Lab1', 1017.48)
# ('2026-07-19 15:42:48', 'DEV055', 'Pressure_Sensor', 'Lab1', 992.9)
# ('2026-07-19 15:42:52', 'DEV059', 'Light_Sensor', 'Lab1', 484.42)
# ('2026-07-19 15:42:58', 'DEV065', 'Temperature_Sensor', 'Lab1', 24.27)
# ('2026-07-19 15:43:03', 'DEV070', 'Light_Sensor', 'Lab1', 872.72)
# ('2026-07-19 15:43:14', 'DEV081', 'Pressure_Sensor', 'Lab1', 1014.3)
# ('2026-07-19 15:43:17', 'DEV084', 'Humidity_Sensor', 'Lab1', 66.37)
# ('2026-07-19 15:43:22', 'DEV089', 'Temperature_Sensor', 'Lab1', 25.09)
# ('2026-07-19 15:43:24', 'DEV091', 'Humidity_Sensor', 'Lab1', 51.5)
# ('2026-07-19 15:43:26', 'DEV093', 'Pressure_Sensor', 'Lab1', 996.82)
# ('2026-07-19 15:43:30', 'DEV097', 'Light_Sensor', 'Lab1', 175.94)
# 24.960499999999993
# [2026-07-19 15:41:56] Device DEV003 at Lab1: 24.12°C
# [2026-07-19 15:42:01] Device DEV008 at OfficeB: 18.99°C
# [2026-07-19 15:42:06] Device DEV013 at Lab2: 22.15°C
# [2026-07-19 15:42:11] Device DEV018 at OfficeB: 28.76°C
# [2026-07-19 15:42:13] Device DEV020 at Lab2: 28.95°C
# [2026-07-19 15:42:17] Device DEV024 at OfficeB: 20.75°C
# [2026-07-19 15:42:21] Device DEV028 at OfficeB: 28.64°C
# [2026-07-19 15:42:30] Device DEV037 at Lab2: 26.48°C
# [2026-07-19 15:42:33] Device DEV040 at Lab2: 29.01°C
# [2026-07-19 15:42:36] Device DEV043 at OfficeA: 23.12°C
# [2026-07-19 15:42:37] Device DEV044 at Warehouse: 19.05°C
# [2026-07-19 15:42:38] Device DEV045 at Warehouse: 28.28°C
# [2026-07-19 15:42:39] Device DEV046 at Lab1: 29.94°C
# [2026-07-19 15:42:43] Device DEV050 at OfficeA: 23.27°C
# [2026-07-19 15:42:46] Device DEV053 at Lab2: 18.4°C
# [2026-07-19 15:42:50] Device DEV057 at Lab2: 29.28°C
# [2026-07-19 15:42:58] Device DEV065 at Lab1: 24.27°C
# [2026-07-19 15:43:08] Device DEV075 at OfficeB: 26.65°C
# [2026-07-19 15:43:10] Device DEV077 at Warehouse: 24.01°C
# [2026-07-19 15:43:22] Device DEV089 at Lab1: 25.09°C
#
# --- Task 3: Core Library Usage ---
#
# Directory 'sensor_reports' already exists.
#
# Duration of data collection: 0 days, 0 hours, 1 minutes.
#
# --- Task 4: File I/O ---
#
# Temperature report written to 'sensor_reports/temperature_report.txt'.
#
# --- Exercise Complete! ---
# Great job completing the intermediate Python exercise.
# Review your code and outputs to ensure correctness and understanding of all concepts.
# Consider adding more complex scenarios or user inputs for further practice.
